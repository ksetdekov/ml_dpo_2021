# %% [markdown]
# ### Part 1. Imbalanced dataset

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: joblib>=0.11 in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (from imbalanced-learn) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: scikit-learn>=0.24 in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/annakuzina/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt


plt.style.use('seaborn')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# [Thyroid Disease Data Set](https://archive.ics.uci.edu/ml/datasets/thyroid+disease): classify patients

# %%
df = pd.read_csv('thyroid_disease.csv')

# %%
df.shape
# Out:
# (3772, 30)

# %%
df.head()
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ... TT4_measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
#      TT4 T4U_measured   T4U FTI_measured    FTI TBG_measured  TBG  \
# 0  125.0            t  1.14            t  109.0            f  NaN
# 1  102.0            f   NaN            f    NaN            f  NaN
# 2  109.0            t  0.91            t  120.0            f  NaN
# 3  175.0            f   NaN            f    NaN            f  NaN
# 4   61.0            t  0.87            t   70.0            f  NaN
#
#   referral_source     Class
# 0            SVHC  negative
# 1           other  negative
# 2           other  negative
# 3           other  negative
# 4             SVI  negative
#
# [5 rows x 30 columns]

# %%
df['Class'].value_counts()
# Out:
# negative    3541
# sick         231
# Name: Class, dtype: int64

# %%
np.round(df.isnull().mean()*100)
# Out:
# age                            0.0
# sex                            4.0
# on_thyroxine                   0.0
# query_on_thyroxine             0.0
# on_antithyroid_medication      0.0
# sick                           0.0
# pregnant                       0.0
# thyroid_surgery                0.0
# I131_treatment                 0.0
# query_hypothyroid              0.0
# query_hyperthyroid             0.0
# lithium                        0.0
# goitre                         0.0
# tumor                          0.0
# hypopituitary                  0.0
# psych                          0.0
# TSH_measured                   0.0
# TSH                           10.0
# T3_measured                    0.0
# T3                            20.0
# TT4_measured                   0.0
# TT4                            6.0
# T4U_measured                   0.0
# T4U                           10.0
# FTI_measured                   0.0
# FTI                           10.0
# TBG_measured                   0.0
# TBG                          100.0
# referral_source                0.0
# Class                          0.0
# dtype: float64

# %% [markdown]
# ### Задание 1.
#
# Есть ли в данных бесполезные колонки? Если да, удалите их.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задание 2.
#
# Ипользуя `LabelEncoder` закодируйте целевую переменную.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# YOUR CODE HERE

# %%
np.unique(df['Class'], return_counts=True)
# Out:
# (array([0, 1]), array([3541,  231]))

# %% [markdown]
# ### Категориальные переменные

# %%
df.describe(include='object')
# Out:
#          sex on_thyroxine query_on_thyroxine on_antithyroid_medication  sick  \
# count   3622         3772               3772                      3772  3772
# unique     2            2                  2                         2     2
# top        F            f                  f                         f     f
# freq    2480         3308               3722                      3729  3625
#
#        pregnant thyroid_surgery I131_treatment query_hypothyroid  \
# count      3772            3772           3772              3772
# unique        2               2              2                 2
# top           f               f              f                 f
# freq       3719            3719           3713              3538
#
#        query_hyperthyroid  ... goitre tumor hypopituitary psych TSH_measured  \
# count                3772  ...   3772  3772          3772  3772         3772
# unique                  2  ...      2     2             2     2            2
# top                     f  ...      f     f             f     f            t
# freq                 3535  ...   3738  3676          3771  3588         3403
#
#        T3_measured TT4_measured T4U_measured FTI_measured referral_source
# count         3772         3772         3772         3772            3772
# unique           2            2            2            2               5
# top              t            t            t            t           other
# freq          3003         3541         3385         3387            2201
#
# [4 rows x 21 columns]

# %%
categorical = list(df.iloc[:,(df.dtypes == "object").values].columns)

# %%
df.groupby(['sex']).Class.mean()
# Out:
# sex
# F    0.054839
# M    0.077933
# Name: Class, dtype: float64

# %%
for c in categorical:
    fig, ax = plt.subplots(ncols=2, figsize=(9,3))
    # plot counts
    df[c].value_counts().plot(kind='bar', ax=ax[0])
    
    # plot proportion of positive class
    grouped = df.groupby([c]).Class.mean()
    grouped.plot(kind='bar', ax=ax[1])
    
    # add column name to the title
    fig.suptitle(c, fontsize=14)
    
    # prettify
    ax[0].grid()
    ax[0].set_ylabel('Num. patients')
    ax[1].set_xlabel('')
    ax[1].grid()
    ax[1].set_ylabel('Prop. sick')
# Out:
# <ipython-input-36-28812154c53f>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(ncols=2, figsize=(9,3))

# %%
df['hypopituitary'].value_counts()
# Out:
# f    3771
# t       1
# Name: hypopituitary, dtype: int64

# %%
df.drop('hypopituitary', axis=1, inplace=True)
categorical.remove('hypopituitary')

# %%
df.describe()
# Out:
#                age          TSH           T3          TT4          T4U  \
# count  3771.000000  3403.000000  3003.000000  3541.000000  3385.000000
# mean     51.735879     5.086766     2.013500   108.319345     0.995000
# std      20.084958    24.521470     0.827434    35.604248     0.195457
# min       1.000000     0.005000     0.050000     2.000000     0.250000
# 25%      36.000000     0.500000     1.600000    88.000000     0.880000
# 50%      54.000000     1.400000     2.000000   103.000000     0.980000
# 75%      67.000000     2.700000     2.400000   124.000000     1.080000
# max     455.000000   530.000000    10.600000   430.000000     2.320000
#
#                FTI        Class
# count  3387.000000  3772.000000
# mean    110.469649     0.061241
# std      33.089698     0.239803
# min       2.000000     0.000000
# 25%      93.000000     0.000000
# 50%     107.000000     0.000000
# 75%     124.000000     0.000000
# max     395.000000     1.000000

# %%
numerical = list(df.iloc[:,(df.dtypes != "object").values].columns)
numerical.remove('Class')

# %%
for c in numerical:
    df.hist(column=c, by='Class', bins=10, sharey=True, sharex=True, figsize=(8,3), density=True);
    plt.suptitle(c)

# %%
### Выделим целевую переменную
y = df['Class']
X = df.drop(['Class'], axis=1)

# %% [markdown]
# Разобъем данные на тренировочную и тестовую выборки

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=13)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(np.round((y_train == 1).mean(), 4), np.round((y_test == 1).mean(), 4))
# Out:
# (2829, 26) (943, 26) (2829,) (943,)
# 0.0633 0.0551

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25, random_state=13)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(np.round((y_train == 1).mean(), 4), np.round((y_test == 1).mean(), 4))
# Out:
# (2829, 26) (943, 26) (2829,) (943,)
# 0.0612 0.0615

# %% [markdown]
# ### Задание 3: Препроцессинг данных
#
# * Категориальные переменные:
#     - заполните пропуски значением `unknown`
#     - закодировать 'OneHotEncoder'
# * Числовые признаки
#      - заполнить пропуски средним
#
#
# Будем использовать комбинацию `make_pipeline` и `ColumnTransformer`
#
# * `make_pipeline` - позволяет объединить несколько трансформеров в один
# * `ColumnTransformer` - позволяет применять разные трансформеры / пайплайны к разным колонкам

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

# %%
# define tranformation/pipeline to preprocess categorical features
categ_transform = make_pipeline(
        # your code here
                    )

# define tranformation/pipeline to preprocess numeric features
numeric_transform =         # your code here

# %% [markdown]
# categorical`ColumnTransformer` принимает на вход список трансформаций. Для каждой можно задать имя и список фичей, к которым применить транформацию:
#
# ```
# ColumnTransformer([
#     ('name1', transorm1, column_names1),
#     ('name2', transorm2, column_names2)
# ])
# ```
#
# Также стоит обратить внимание на аргумент `remainder='passthrough'`, если вы хотите оставить некоторые колонки нетронутыми.

# %%
column_transformer = ColumnTransformer([
        # your code here
], remainder='passthrough')


X_train =          # your code here
X_test =         # your code here

# %% [markdown]
# ### Обучение и вывод метрик

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# матрица ошибок
def compute_confusion_matrix(y_test, y_pred):
    return pd.DataFrame(
        confusion_matrix(y_test, y_pred, labels=[1, 0]),
        columns=['a(x) = 1', 'a(x) = 0'],
        index=['y = 1', 'y = 0'],
    ).T

# метрики
def compute_metrics(y_test, y_pred):
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, y_pred)))
    print('F-score: {:.2f}'.format(f1_score(y_test, y_pred)))
    print('Precision: {:.2f}'.format(precision_score(y_test, y_pred)))
    print('Recall: {:.2f}'.format(recall_score(y_test, y_pred)))
    return f1_score(y_test, y_pred)

# %%
test_results  = {}

# %% [markdown]
# ### Задание 4
# Заполните пропуски в функции eval_model, используйте ее для обучение RandomForest c 50 деревьями.

# %%
def eval_model(model, X_train, y_train, X_test, y_test):
    # fit model

    
    # compute cofusion matrix

    
    # compute metrics

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, random_state=13)
f_score = eval_model(rf, X_train, y_train, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     45      4
# a(x) = 0     13    881
# Accuracy: 0.98
# F-score: 0.84
# Precision: 0.92
# Recall: 0.78

# %%
test_results['RF'] = f_score

# %%
rf = RandomForestClassifier(n_estimators=50, class_weight='balanced', random_state=13)
test_results['RF balanced'] = eval_model(rf, X_train, y_train, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     45      4
# a(x) = 0     13    881
# Accuracy: 0.98
# F-score: 0.84
# Precision: 0.92
# Recall: 0.78

# %%
(y_train == 1).mean(), (y_test == 1).mean()
# Out:
# (0.06115235065394132, 0.061505832449628844)

# %% [markdown]
# # Undersampling

# %% [markdown]
# ## Random

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
us = RandomUnderSampler(random_state=13)
X_train_rs, y_train_rs = us.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (346, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['Random Undersamp.'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     56     25
# a(x) = 0      2    860
# Accuracy: 0.97
# F-score: 0.81
# Precision: 0.69
# Recall: 0.97

# %% [markdown]
# Слишком мало тренировочных данных. Уберем поменьше

# %%
us = RandomUnderSampler(sampling_strategy=0.2, random_state=13)
X_train_rs, y_train_rs = us.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (1038, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced', )
test_results['Random Undersamp.'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     50      6
# a(x) = 0      8    879
# Accuracy: 0.99
# F-score: 0.88
# Precision: 0.89
# Recall: 0.86

# %% [markdown]
# ## NearMiss

# %%
from imblearn.under_sampling import NearMiss

us = NearMiss(sampling_strategy=0.2, n_neighbors=3, version=1)
X_train_rs, y_train_rs = us.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (1038, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['NearMiss-1'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     57     36
# a(x) = 0      1    849
# Accuracy: 0.96
# F-score: 0.75
# Precision: 0.61
# Recall: 0.98

# %%
us = NearMiss(sampling_strategy=0.2, n_neighbors=3, version=2)
X_train_rs, y_train_rs = us.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['NearMiss-2'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
# (2829, 50) (1038, 50)
#           y = 1  y = 0
# a(x) = 1     57     60
# a(x) = 0      1    825
# Accuracy: 0.94
# F-score: 0.65
# Precision: 0.49
# Recall: 0.98

# %%
us = NearMiss(sampling_strategy=0.2, n_neighbors=3, version=3)
X_train_rs, y_train_rs = us.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['NearMiss-3'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
# (2829, 50) (541, 50)
#           y = 1  y = 0
# a(x) = 1     51      8
# a(x) = 0      7    877
# Accuracy: 0.98
# F-score: 0.87
# Precision: 0.86
# Recall: 0.88
# /Users/annakuzina/anaconda3/lib/python3.8/site-packages/imblearn/under_sampling/_prototype_selection/_nearmiss.py:175: UserWarning: The number of the samples to be selected is larger than the number of samples available. The balancing ratio cannot be ensure and all samples will be returned.
#   warnings.warn(

# %% [markdown]
# # Oversampling

# %% [markdown]
# ## Random

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
os = RandomOverSampler(sampling_strategy=0.8, random_state=13)
X_train_rs, y_train_rs = os.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (4780, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['Random Oversamp.'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     46      4
# a(x) = 0     12    881
# Accuracy: 0.98
# F-score: 0.85
# Precision: 0.92
# Recall: 0.79

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE
os = SMOTE(sampling_strategy=0.8, k_neighbors=5, random_state=13)
X_train_rs, y_train_rs = os.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (4780, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['SMOTE'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     48      4
# a(x) = 0     10    881
# Accuracy: 0.99
# F-score: 0.87
# Precision: 0.92
# Recall: 0.83

# %% [markdown]
# ## BorderlineSMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE
os = BorderlineSMOTE(sampling_strategy=0.8, kind='borderline-1', random_state=13)
X_train_rs, y_train_rs = os.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (4780, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['BorderlineSMOTE-1'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     49      5
# a(x) = 0      9    880
# Accuracy: 0.99
# F-score: 0.88
# Precision: 0.91
# Recall: 0.84

# %%
os = BorderlineSMOTE(sampling_strategy=0.8, kind='borderline-2', random_state=13)
X_train_rs, y_train_rs = os.fit_resample(X_train, y_train)
print(X_train.shape, X_train_rs.shape)
# Out:
# (2829, 50) (4780, 50)

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=13, class_weight='balanced')
test_results['BorderlineSMOTE-2'] = eval_model(rf, X_train_rs, y_train_rs, X_test, y_test)
# Out:
#           y = 1  y = 0
# a(x) = 1     49      6
# a(x) = 0      9    879
# Accuracy: 0.98
# F-score: 0.87
# Precision: 0.89
# Recall: 0.84

# %% [markdown]
# ### Задание 5
#
# * Используя SMOTE увеличьте долю миноритораного класса до 0.5 (oversampling)
# * Используя NearMiss увеличьте долю миноритораного класса до 1 (undersampling)
# * Обучить модель на полученной выборке

# %%
# oversampling

# undersampling

# train model

# %% [markdown]
# ### Final Plot

# %%
plt.plot(test_results.values())
plt.xticks(range(len(test_results)), labels=test_results.keys(), fontsize=14, rotation='vertical');
plt.ylim(0.8, 0.9)
# Out:
# (0.8, 0.9)

# %% [markdown]
# ### Unsupervised Anomaly Detection

# %% [markdown]
# Сгенерируем игрушечные датасеты

# %%
from sklearn.datasets import make_moons, make_blobs

datasets = [
    make_blobs(centers=[[0, 0], [0, 0]], cluster_std=0.5, n_samples=255, n_features=2, random_state=13)[0],
    make_blobs(centers=[[2, 2], [-2, -2]], cluster_std=[0.5, 0.5], n_samples=255, n_features=2, random_state=13)[0],
    make_blobs(centers=[[2, 2], [-2, -2]], cluster_std=[1.5, .3], n_samples=255, n_features=2, random_state=13)[0],
    4. * (make_moons(n_samples=255, noise=.05, random_state=0)[0] - np.array([0.5, 0.25])),
    14. * (np.random.RandomState(42).rand(255, 2) - 0.5)
]

fig, ax = plt.subplots(ncols = len(datasets), figsize=(len(datasets)*3, 3))
for i in range(len(datasets)):
    ax[i].scatter(datasets[i][:, 0], datasets[i][:, 1]);

# %% [markdown]
# Добавим шум

# %%
fig, ax = plt.subplots(ncols = len(datasets), figsize=(len(datasets)*3, 3))
    
np.random.seed(123)
for i in range(len(datasets)):
    datasets[i] = np.concatenate([datasets[i], np.random.uniform(low=-6, high=6, size=(45, 2))], axis=0)
    ax[i].scatter(datasets[i][:255, 0], datasets[i][:255, 1]);
    ax[i].scatter(datasets[i][255:, 0], datasets[i][255:, 1]);

# %%
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# ### Local Outlier Factor
#
# ### Задание 6
#
# Найдите аномалии с помощью Local Outlier Factor, раскрасте аномальные точки отличным цветом на графике. Доля аномалий - 15%.

# %%
fig, ax = plt.subplots(ncols = len(datasets), figsize=(len(datasets)*3, 3))
for i in range(len(datasets)):
    # choose dataset
    X = datasets[i]

    # find anomalies

    
    # draw scatter plot

# %% [markdown]
# ### One-Class SVM
#
# ### Задание 7
#
# Найдите аномалии с помощью One-Class SVM c линейныс ядром и ядром 'rbf', раскрасте аномальные точки отличным цветом на графике. Доля аномалий - 15%.

# %%
fig, ax = plt.subplots(ncols = len(datasets), figsize=(len(datasets)*3, 3))
for i in range(len(datasets)):
    X = datasets[i]
    # svm with linear kernel
    
    # scatter plot

# %%
fig, ax = plt.subplots(ncols = len(datasets), figsize=(len(datasets)*3, 3))
for i in range(len(datasets)):
    X = datasets[i]
    # svm with rbf kernel

    # scatter plot

# %% [markdown]
# ### Isolation Forest
#
# ### Задание 8
#
# Найдите аномалии с помощью Isolation Forest. Попробуйте от 5 до 20% аномалий.
